# %%
# %%timeit -n 3

import pandas as pd

df = pd.read_excel("week3/assets/صلاحيات بلدي أعمال.xlsx")
# df.set_index("maapingId")
# Out:
# 124 ms ± 1.68 ms per loop (mean ± std. dev. of 7 runs, 3 loops each)

# %%
grouped = df.groupby("CategoryName")
grouped
# Out:
# <bound method GroupBy.all of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000028919055310>>

# %%
df = grouped.apply(lambda x: x,include_groups=False)
df
# Out:
#                                                                          ServiceName  \
# CategoryName
# إتمام لخدمات التطوير العقاري 719   اعتماد البنية التحتية لهيئة الاتصالات والفضاء ...
#                              720   اعتماد البنية التحتية لهيئة الاتصالات والفضاء ...
#                              721   اعتماد البنية التحتية لهيئة الاتصالات والفضاء ...
#                              722   اعتماد البنية التحتية لهيئة الاتصالات والفضاء ...
#                              723   اعتماد البنية التحتية لهيئة الاتصالات والفضاء ...
# ...                                                                              ...
# خدمات منصة انجاز             1205                           طلب استكمال بيانات العقد
#                              1206                           طلب استكمال بيانات العقد
#                              1207                           طلب استكمال بيانات العقد
#                              1208                           طلب استكمال بيانات العقد
# ...
